# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
rsp = gpd.read_file("rsp-data/rsp-3.geojson")

# %%
rsp.head()
# Out:
#    fid Tag       Date     Time Temp (C) Baro (mb)    Depth (m)    pH  \
# 0    1   1  6/10/2019  9:51:00     28.3      1014  0.059999999  7.32
# 1    2   2  6/10/2019  9:52:00     28.4      1014  0.189999998   7.2
# 2    3   3  6/10/2019  9:52:00     28.4      1014  0.090000004   7.2
# 3    4   4  6/10/2019  9:52:00    28.48      1014  0.159999996  7.21
# 4    5   5  6/10/2019  9:53:00     28.5      1014  0.120000005  7.22
#
#   ORP (REDOX) DO (% Sat)  ... _variety _variance HISTO_crops HISTO_water  \
# 0         9.5      494.6  ...      5.0  3.757342         679         839
# 1        17.1      494.7  ...      5.0  3.835843         657         825
# 2        20.5      494.7  ...      5.0  3.895659         634         821
# 3        22.6      494.9  ...      5.0  3.916712         625         815
# 4        26.5      494.9  ...      5.0  3.940420         615         817
#
#   HISTO_mangrove HISTO_forest HISTO_grassland HISTO_settlements  \
# ...

# %%
rsp.columns
# Out:
# Index(['fid', 'Tag', 'Date', 'Time', 'Temp (C)', 'Baro (mb)', 'Depth (m)',
#        'pH', 'ORP (REDOX)', 'DO (% Sat)', 'DO (mg/L)', 'EC (uS/cm @25C)',
#        'RES (Ohms.cm)', 'TDS (mg/L)', 'SAL (PSU)', 'SSG (st)',
#        'Turbidity (NTU)', 'Nitrate (mg/L)', 'Lat', 'Lon', 'Alt (m)',
#        'r2r distance', 'Distance from FSC', 'Lat_DD', 'Lon_DD', 'Lat_filled',
#        'Lon_filled', '_count', '_sum', '_mean', '_median', '_stdev', '_min',
#        '_max', '_range', '_minority', '_majority', '_variety', '_variance',
#        'HISTO_crops', 'HISTO_water', 'HISTO_mangrove', 'HISTO_forest',
#        'HISTO_grassland', 'HISTO_settlements', 'HISTO_bare_land', 'geometry'],
#       dtype='object')
